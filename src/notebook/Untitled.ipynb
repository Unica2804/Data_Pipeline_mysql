# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv("/home/unica/Developer/Ml_Program/Python_Projects/SQL_Project/data/patients.csv")

# %%
data1.isnull().sum()
# Out:
# patient_id        0
# name              0
# age               0
# arrival_date      0
# departure_date    0
# service           0
# satisfaction      0
# dtype: int64

# %%
data2=pd.read_csv("/home/unica/Developer/Ml_Program/Python_Projects/SQL_Project/data/services_weekly.csv")

# %%
data2.isnull().sum()
# Out:
# week                    0
# month                   0
# service                 0
# available_beds          0
# patients_request        0
# patients_admitted       0
# patients_refused        0
# patient_satisfaction    0
# staff_morale            0
# event                   0
# dtype: int64

# %%
data2.head(0)
# Out:
# Empty DataFrame
# Columns: [week, month, service, available_beds, patients_request, patients_admitted, patients_refused, patient_satisfaction, staff_morale, event]
# Index: []

# %%
data3=pd.read_csv("/home/unica/Developer/Ml_Program/Python_Projects/SQL_Project/data/staff_schedule.csv")
data3.isnull().sum()
# Out:
# week          0
# staff_id      0
# staff_name    0
# role          0
# service       0
# present       0
# dtype: int64

# %%
data4=pd.read_csv("/home/unica/Developer/Ml_Program/Python_Projects/SQL_Project/data/staff.csv")
data4.isnull().sum()
# Out:
# staff_id      0
# staff_name    0
# role          0
# service       0
# dtype: int64
